# %%
import pandas as pd
import numpy as np

# %%
from typing import cast
from zappai.database.di import get_session_maker
from zappai.zappai.di import (
    get_cds_api,
    get_climate_generative_model_repository,
    get_future_climate_data_repository,
    get_location_repository,
    get_past_climate_data_repository,
)
from zappai.zappai.dtos import (
    ClimateDataDTO,
    FutureClimateDataDTO,
    LocationDTO,
)
from zappai.zappai.utils import common


session_maker = get_session_maker()
cds_api = get_cds_api()
location_repository = get_location_repository()
past_climate_data_repository = get_past_climate_data_repository(
    cds_api=cds_api,
    location_repository=location_repository,
)
future_climate_data_repository = get_future_climate_data_repository(cds_api=cds_api)
climate_generative_model_repository = get_climate_generative_model_repository(
    location_repository=location_repository,
    past_climate_data_repository=past_climate_data_repository,
    future_climate_data_repository=future_climate_data_repository,
)

async with session_maker() as session:
    location = await location_repository.get_location_by_country_and_name(
        session=session,
        country=common.EXAMPLE_LOCATION_COUNTRY,
        name=common.EXAMPLE_LOCATION_NAME,
    )
# Out:
# 2024-07-16 16:07:51.266604: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-16 16:07:51.269058: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-16 16:07:51.301927: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-16 16:07:51.991472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
location = cast(LocationDTO, location)

async with session_maker() as session:
    await climate_generative_model_repository.delete_climate_generative_model(
        session=session, location_id=location.id
    )
    climate_generative_model = (
        await climate_generative_model_repository.create_model_for_location(
            session=session, location_id=location.id
        )
    )
    await session.commit()

model = climate_generative_model.model
x_scaler = climate_generative_model.x_scaler
y_scaler = climate_generative_model.y_scaler
# Out:
# 2024-07-16 16:07:52.908607: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-16 16:07:52.909312: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.9405 - root_mean_squared_error: 0.9684 - val_loss: 0.3052 - val_root_mean_squared_error: 0.5525
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2960 - root_mean_squared_error: 0.5435 - val_loss: 0.1560 - val_root_mean_squared_error: 0.3949
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2209 - root_mean_squared_error: 0.4697 - val_loss: 0.1567 - val_root_mean_squared_error: 0.3959
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2271 - root_mean_squared_error: 0.4764 - val_loss: 0.1488 - val_root_mean_squared_error: 0.3857
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2037 - root_mean_squared_error: 0.4513 - val_loss: 0.1400 - val_root_mean_squared_error: 0.3742
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2051 - root_mean_squared_error: 0.4527 - val_loss: 0.1397 - val_root_mean_squared_error: 0.3737
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1873 - root_mean_squared_error: 0.4327 - val_loss: 0.1346 - val_root_mean_squared_error: 0.3668
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1916 - root_mean_squared_error: 0.4374 - val_loss: 0.1351 - val_root_mean_squared_error: 0.3676
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1927 - root_mean_squared_error: 0.4388 - val_loss: 0.1322 - val_root_mean_squared_error: 0.3636
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1737 - root_mean_squared_error: 0.4168 - val_loss: 0.1362 - val_root_mean_squared_error: 0.3691
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1909 - root_mean_squared_error: 0.4367 - val_loss: 0.1260 - val_root_mean_squared_error: 0.3550
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1818 - root_mean_squared_error: 0.4263 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3663
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1865 - root_mean_squared_error: 0.4315 - val_loss: 0.1319 - val_root_mean_squared_error: 0.3632
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1718 - root_mean_squared_error: 0.4144 - val_loss: 0.1322 - val_root_mean_squared_error: 0.3635
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1642 - root_mean_squared_error: 0.4052 - val_loss: 0.1231 - val_root_mean_squared_error: 0.3508
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1705 - root_mean_squared_error: 0.4129 - val_loss: 0.1179 - val_root_mean_squared_error: 0.3434
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1606 - root_mean_squared_error: 0.4005 - val_loss: 0.1213 - val_root_mean_squared_error: 0.3482
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1646 - root_mean_squared_error: 0.4056 - val_loss: 0.1143 - val_root_mean_squared_error: 0.3381
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1580 - root_mean_squared_error: 0.3974 - val_loss: 0.1209 - val_root_mean_squared_error: 0.3476
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1571 - root_mean_squared_error: 0.3962 - val_loss: 0.1129 - val_root_mean_squared_error: 0.3360
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1503 - root_mean_squared_error: 0.3876 - val_loss: 0.1142 - val_root_mean_squared_error: 0.3379
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1442 - root_mean_squared_error: 0.3795 - val_loss: 0.1183 - val_root_mean_squared_error: 0.3439
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1523 - root_mean_squared_error: 0.3901 - val_loss: 0.1141 - val_root_mean_squared_error: 0.3377
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1511 - root_mean_squared_error: 0.3886 - val_loss: 0.1151 - val_root_mean_squared_error: 0.3392
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1451 - root_mean_squared_error: 0.3807 - val_loss: 0.1168 - val_root_mean_squared_error: 0.3418
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1528 - root_mean_squared_error: 0.3904 - val_loss: 0.1099 - val_root_mean_squared_error: 0.3314
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1458 - root_mean_squared_error: 0.3817 - val_loss: 0.1103 - val_root_mean_squared_error: 0.3321
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1421 - root_mean_squared_error: 0.3768 - val_loss: 0.1085 - val_root_mean_squared_error: 0.3293
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1355 - root_mean_squared_error: 0.3679 - val_loss: 0.1105 - val_root_mean_squared_error: 0.3324
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1426 - root_mean_squared_error: 0.3775 - val_loss: 0.1198 - val_root_mean_squared_error: 0.3461
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1370 - root_mean_squared_error: 0.3698 - val_loss: 0.1197 - val_root_mean_squared_error: 0.3460
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1375 - root_mean_squared_error: 0.3708 - val_loss: 0.1075 - val_root_mean_squared_error: 0.3279
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1476 - root_mean_squared_error: 0.3839 - val_loss: 0.1104 - val_root_mean_squared_error: 0.3322
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1430 - root_mean_squared_error: 0.3781 - val_loss: 0.1031 - val_root_mean_squared_error: 0.3210
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1379 - root_mean_squared_error: 0.3712 - val_loss: 0.1154 - val_root_mean_squared_error: 0.3397
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1337 - root_mean_squared_error: 0.3656 - val_loss: 0.1094 - val_root_mean_squared_error: 0.3308
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1476 - root_mean_squared_error: 0.3838 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1291 - root_mean_squared_error: 0.3592 - val_loss: 0.1152 - val_root_mean_squared_error: 0.3393
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1306 - root_mean_squared_error: 0.3612 - val_loss: 0.1093 - val_root_mean_squared_error: 0.3306
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1439 - root_mean_squared_error: 0.3793 - val_loss: 0.1122 - val_root_mean_squared_error: 0.3350
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1341 - root_mean_squared_error: 0.3661 - val_loss: 0.1088 - val_root_mean_squared_error: 0.3298
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1353 - root_mean_squared_error: 0.3677 - val_loss: 0.1081 - val_root_mean_squared_error: 0.3288
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1338 - root_mean_squared_error: 0.3658 - val_loss: 0.1145 - val_root_mean_squared_error: 0.3384
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1338 - root_mean_squared_error: 0.3657 - val_loss: 0.1097 - val_root_mean_squared_error: 0.3312
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1355 - root_mean_squared_error: 0.3681 - val_loss: 0.1118 - val_root_mean_squared_error: 0.3344
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1205 - root_mean_squared_error: 0.3464 - val_loss: 0.1053 - val_root_mean_squared_error: 0.3245
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1270 - root_mean_squared_error: 0.3563 - val_loss: 0.1055 - val_root_mean_squared_error: 0.3247
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1291 - root_mean_squared_error: 0.3592 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3290
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1321 - root_mean_squared_error: 0.3634 - val_loss: 0.1116 - val_root_mean_squared_error: 0.3340
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1308 - root_mean_squared_error: 0.3615 - val_loss: 0.1069 - val_root_mean_squared_error: 0.3270
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1458 - root_mean_squared_error: 0.3814

# %%
from zappai.zappai.repositories.climate_generative_model_repository import (
    FEATURES_WITH_SIN_COS,
    TARGET,
    SEQ_LENGTH,
    add_sin_cos_year,
)


async with session_maker() as session:
    df_test = ClimateDataDTO.from_list_to_dataframe(
    await past_climate_data_repository.get_past_climate_data(
            session=session,
            location_id=location.id,
            year_from=climate_generative_model.test_start_year,
            month_from=climate_generative_model.test_start_month,
            year_to=climate_generative_model.test_end_year,
            month_to=climate_generative_model.test_end_month,
        )
    )

df_test = add_sin_cos_year(df_test)

# %%
x_df_test = df_test[FEATURES_WITH_SIN_COS]
x_df_test
# Out:
#             surface_solar_radiation_downwards  \
# year month
# 2011 10                          1.192052e+07
#      11                          7.867499e+06
#      12                          6.771313e+06
# 2012 1                           8.295657e+06
#      2                           8.984526e+06
# ...                                       ...
# 2024 2                           1.103211e+07
#      3                           1.623242e+07
#      4                           2.111158e+07
#      5                           2.225734e+07
#      6                           2.702775e+07
#
#             surface_thermal_radiation_downwards  surface_net_solar_radiation  \
# year month
# 2011 10                            2.856999e+07                 1.067037e+07
#      11                            2.756182e+07                 7.057508e+06
#      12                            2.541200e+07                 6.069447e+06
# 2012 1                             2.357119e+07                 7.405434e+06
#      2                             2.516410e+07                 7.888859e+06
# ...                                         ...                          ...
# 2024 2                             2.576133e+07                 9.841429e+06
#      3                             2.616479e+07                 1.449971e+07
#      4                             2.717887e+07                 1.886191e+07
#      5                             2.969656e+07                 1.992405e+07
#      6                             3.171924e+07                 2.423653e+07
#
#             surface_net_thermal_radiation  total_cloud_cover  \
# year month
# 2011 10                     -6.596848e+06           0.427252
#      11                     -5.707553e+06           0.526097
#      12                     -6.428651e+06           0.434871
# 2012 1                      -7.192958e+06           0.368344
#      2                      -5.439420e+06           0.630574
# ...                                   ...                ...
# 2024 2                      -6.344076e+06           0.466573
#      3                      -6.661283e+06           0.478982
#      4                      -7.231584e+06           0.405940
#      5                      -6.320944e+06           0.516750
#      6                      -7.692243e+06           0.239848
#
#             2m_dewpoint_temperature  soil_temperature_level_3  \
# year month
# 2011 10                  284.729434                293.741419
#      11                  283.043408                289.806455
#      12                  279.451805                286.558917
# 2012 1                   275.281463                283.667371
#      2                   275.892448                282.454511
# ...                             ...                       ...
# 2024 2                   281.087708                285.261142
#      3                   282.018877                286.256922
#      4                   283.168098                288.858824
#      5                   287.139088                291.249895
#      6                   290.095587                296.350498
#
#             volumetric_soil_water_layer_3      sin_year      cos_year  \
# year month
# 2011 10                          0.152529 -8.660254e-01  5.000000e-01
#      11                          0.162347 -5.000000e-01  8.660254e-01
#      12                          0.191056 -2.449294e-16  1.000000e+00
# 2012 1                           0.203387  5.000000e-01  8.660254e-01
#      2                           0.240692  8.660254e-01  5.000000e-01
# ...                                   ...           ...           ...
# 2024 2                           0.178380  8.660254e-01  5.000000e-01
#      3                           0.196695  1.000000e+00  6.123234e-17
#      4                           0.190879  8.660254e-01 -5.000000e-01
#      5                           0.173759  5.000000e-01 -8.660254e-01
#      6                           0.162444  1.224647e-16 -1.000000e+00
#
#             2m_temperature  total_precipitation
# year month
# 2011 10         290.862260             0.001613
#      11         287.150551             0.003173
#      12         284.456450             0.001412
# 2012 1          281.515102             0.001162
#      2          280.743743             0.006076
# ...                    ...                  ...
# 2024 2          285.610095             0.002229
#      3          286.796737             0.000971
#      4          289.575987             0.001208
#      5          292.594924             0.001128
#      6          298.957983             0.000054
#
# [153 rows x 12 columns]

# %%
y_df_test = df_test[TARGET]
y_df_test
# Out:
#             surface_solar_radiation_downwards  \
# year month
# 2011 10                          1.192052e+07
#      11                          7.867499e+06
#      12                          6.771313e+06
# 2012 1                           8.295657e+06
#      2                           8.984526e+06
# ...                                       ...
# 2024 2                           1.103211e+07
#      3                           1.623242e+07
#      4                           2.111158e+07
#      5                           2.225734e+07
#      6                           2.702775e+07
#
#             surface_thermal_radiation_downwards  surface_net_solar_radiation  \
# year month
# 2011 10                            2.856999e+07                 1.067037e+07
#      11                            2.756182e+07                 7.057508e+06
#      12                            2.541200e+07                 6.069447e+06
# 2012 1                             2.357119e+07                 7.405434e+06
#      2                             2.516410e+07                 7.888859e+06
# ...                                         ...                          ...
# 2024 2                             2.576133e+07                 9.841429e+06
#      3                             2.616479e+07                 1.449971e+07
#      4                             2.717887e+07                 1.886191e+07
#      5                             2.969656e+07                 1.992405e+07
#      6                             3.171924e+07                 2.423653e+07
#
#             surface_net_thermal_radiation  total_cloud_cover  \
# year month
# 2011 10                     -6.596848e+06           0.427252
#      11                     -5.707553e+06           0.526097
#      12                     -6.428651e+06           0.434871
# 2012 1                      -7.192958e+06           0.368344
#      2                      -5.439420e+06           0.630574
# ...                                   ...                ...
# 2024 2                      -6.344076e+06           0.466573
#      3                      -6.661283e+06           0.478982
#      4                      -7.231584e+06           0.405940
#      5                      -6.320944e+06           0.516750
#      6                      -7.692243e+06           0.239848
#
#             2m_dewpoint_temperature  soil_temperature_level_3  \
# year month
# 2011 10                  284.729434                293.741419
#      11                  283.043408                289.806455
#      12                  279.451805                286.558917
# 2012 1                   275.281463                283.667371
#      2                   275.892448                282.454511
# ...                             ...                       ...
# 2024 2                   281.087708                285.261142
#      3                   282.018877                286.256922
#      4                   283.168098                288.858824
#      5                   287.139088                291.249895
#      6                   290.095587                296.350498
#
#             volumetric_soil_water_layer_3
# year month
# 2011 10                          0.152529
#      11                          0.162347
#      12                          0.191056
# 2012 1                           0.203387
#      2                           0.240692
# ...                                   ...
# 2024 2                           0.178380
#      3                           0.196695
#      4                           0.190879
#      5                           0.173759
#      6                           0.162444
#
# [153 rows x 8 columns]

# %%
if len(TARGET) > 0:
    from typing import cast

    from zappai.zappai.repositories.climate_generative_model_repository import (
        ClimateGenerativeModelRepository,
    )

    print(y_df_test.columns)

    x_test_scaled = cast(np.ndarray, x_scaler.transform(x_df_test.to_numpy()))
    y_test_scaled = cast(np.ndarray, y_scaler.transform(y_df_test.to_numpy()))

    x_test_formatted, y_test_formatted = ClimateGenerativeModelRepository.format_data(
        x=x_test_scaled, y=y_test_scaled
    )

    predictions = model.predict(x_test_formatted)
    inverse_scaled_predictions = cast(
        np.ndarray, y_scaler.inverse_transform(predictions)
    )
    predictions_df = pd.DataFrame(data=inverse_scaled_predictions, columns=TARGET)
    y_df_plot = y_df_test[:-SEQ_LENGTH].copy().reset_index()
    for target in TARGET:
        y_df_plot[f"predicted_{target}"] = predictions_df[target]
    y_df_plot = y_df_plot.set_index(keys=["year", "month"], drop=True)

    if "soil_temperature_level_3" in TARGET:
        y_df_plot["soil_temperature_level_3"] = (
            y_df_plot["soil_temperature_level_3"] - 273.15
        )
        y_df_plot["predicted_soil_temperature_level_3"] = (
            y_df_plot["predicted_soil_temperature_level_3"] - 273.15
        )
        y_df_plot[
            ["soil_temperature_level_3", "predicted_soil_temperature_level_3"]
        ].plot()
# Out:
# Index(['surface_solar_radiation_downwards',
#        'surface_thermal_radiation_downwards', 'surface_net_solar_radiation',
#        'surface_net_thermal_radiation', 'total_cloud_cover',
#        '2m_dewpoint_temperature', 'soil_temperature_level_3',
#        'volumetric_soil_water_layer_3'],
#       dtype='object')
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
# Graph the data from CMIP5 and from ERA5 to confront them, so we can establish which CMIP5 data are actually accurate
from zappai.zappai.repositories.copernicus_data_store_api import (
    ERA5_VARIABLES,
    CMIP5_VARIABLES,
)

MONTHS_BEFORE = 25


true_data_df = df_test[-MONTHS_BEFORE:].copy()

# PLOT DATA
from matplotlib import pyplot as plt


async with session_maker() as session:
    entire_future_climate_data_df = FutureClimateDataDTO.from_list_to_dataframe(
    await future_climate_data_repository.get_future_climate_data_for_nearest_coordinates(
            session=session,
            longitude=location.longitude,
            latitude=location.latitude,
            year_from=1970,
            month_from=1,
            year_to=9999,
            month_to=12,
        )
    )

entire_future_climate_data_df = entire_future_climate_data_df[CMIP5_VARIABLES]
true_data_df = true_data_df[ERA5_VARIABLES]

for variable in CMIP5_VARIABLES:
    true_data_df[f"cmip5_{variable}"] = entire_future_climate_data_df[variable]

for variable in ERA5_VARIABLES:
    true_data_df = true_data_df.rename(columns={variable: f"era5_{variable}"})

# removes the future climate data that is too much into the past or too much into the future
true_data_df = true_data_df.dropna()

cmip5_kelvin_to_celsius = ["2m_temperature"]

for temperature in cmip5_kelvin_to_celsius:
    if temperature in true_data_df.columns:
        true_data_df[temperature] = true_data_df[temperature] - 273.15
        true_data_df[f"cmip5_{temperature}"] = (
            true_data_df[f"cmip5_{temperature}"] - 273.15
        )

for variable in CMIP5_VARIABLES:
    true_data_df[[f"era5_{variable}", f"cmip5_{variable}"]].plot()

# %%
from zappai.zappai.utils.common import get_next_n_months

# GENERATE DATA
seed_data = df_test[(-MONTHS_BEFORE - SEQ_LENGTH) : -MONTHS_BEFORE]
start_year, start_month = seed_data.index[-1]

start_year, start_month = get_next_n_months(n=1, month=start_month, year=start_year)
year_to, month_to = get_next_n_months(n=24, month=start_month, year=start_year)

print(f"start_year: {start_year}")
print(f"start_month: {start_month}")

async with session_maker() as session:
    future_climate_data_df = FutureClimateDataDTO.from_list_to_dataframe(
        (
            await future_climate_data_repository.get_future_climate_data_for_nearest_coordinates(
                session=session,
                longitude=location.longitude,
                latitude=location.latitude,
                year_from=start_year,
                month_from=start_month,
                year_to=year_to,
                month_to=month_to,
            )
        )
    )

# this generated data start from one year ago
generated_data_df = climate_generative_model_repository.generate_data_from_seed(
    model=model,
    x_scaler=x_scaler,
    y_scaler=y_scaler,
    seed_data_df=seed_data,
    future_climate_data_df=future_climate_data_df,
)

predicted_kelvin_to_celsius = ["soil_temperature_level_3", "2m_dewpoint_temperature"]

for predicted_variable in TARGET:
    generated_data_df = generated_data_df[:24]
    generated_data_df[f"actual_{predicted_variable}"] = true_data_df[
        f"era5_{predicted_variable}"
    ]

    generated_data_df = generated_data_df.rename(
        columns={predicted_variable: f"predicted_{predicted_variable}"}
    )

for temperature in predicted_kelvin_to_celsius:
    if temperature in generated_data_df.columns:
        generated_data_df[f"predicted_{temperature}"] = (
            generated_data_df[f"predicted_{temperature}"] - 273.15
        )
        generated_data_df[f"actual_{temperature}"] = (
            generated_data_df[f"actual_{temperature}"] - 273.15
        )

for predicted_variable in TARGET:
    generated_data_df[
        [
            f"predicted_{predicted_variable}",
            f"actual_{predicted_variable}",
        ]
    ].plot()
# Out:
# start_year: 2022
# start_month: 6
